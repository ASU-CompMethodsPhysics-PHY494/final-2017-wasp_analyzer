# %%
import numpy as np
import matplotlib.pyplot as plt

a = 50
b = [[],[]]
c = []

for i in range(51):
    for j in range(51):
        if (i**2 + j**2)>a**2:
            I = 0
            b.append(I)
            break
        else:
            I = 1-0.6096*(1-np.sqrt((a**2 - (i**2 + j**2))/a**2))
            b.append(I)
#print(b)

c = b[::-1] + b[1::]

print(c)
#print(b)
plt.plot(c)
plt.show()
# Out:
# [0, 0.39039999999999997, 0, 0.44212627525735837, 0.46252884471555045, 0.47661045876226382, 0.48717099995349844, 0.49527954965578369, 0.50147440619692729, 0.50606346769831867, 0.50923291665191084, 0.51109464226716939, 0.5117088683320391, 0, 0.39039999999999997, 0.45375149033763928, 0.47831776230091383, 0.49598581722939872, 0.50985671577605007, 0.521144634153758, 0.53047541557318323, 0.53822014412115826, 0.5446179569310915, 0.54983108775894363, 0.55397284469006458, 0.55712309248571412, 0.55933730756703803, 0.5606520146136309, 0.56108800000000003, 0, 0.40764209175245281, 0.46252884471555045, 0.48944827622932152, 0.50923291665191084, 0.52506504152154698, 0.53822014412115826, 0.54936423144846147, 0.55889679232555145, 0.56707886528954154, 0.57409100176110961, 0.58006300927698051, 0.58509062720120864, 0.58924550239821871, 0.59258144722006523, 0.59513849576471922, 0.59694557842761964, 0.59802227857337464, 0.59837993995575633, 0, 0.44887077793222863, 0.48483882591392169, 0.50923291665191084, 
# ...
